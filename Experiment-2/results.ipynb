# %%
import pandas as pd
import numpy as np
import json

# %%
models = [
    'Gradient Boosting',
    'K-Nearest Neighbors',

    'XGBClassifier',

    'Logistic Regression',
    'Ridge',
    'Extra Trees',
    'AdaBoost',

    'Passive Aggressive',
    'Support Vector Classification',
    'Decision Trees',

    'Random Forest',
    'Naive Bayes'

]

# %%
len(models)
# Out:
# 12

# %%
result = {}

# %%
for model in models:
    path = model + '.json'
    with open(path, 'r') as f:
        data = json.load(f)
    result[model] = [data['Train Accuracy'], data['Test Accuracy'], data['Train F1'], data['Test F1'], data['Best Score'], data['Best Params']]

# %%
results = pd.DataFrame(result).T
results.columns = ['Train Accuracy', 'Test Accuracy', 'Train F1', 'Test F1', 'Best Score', 'Best Params']
results
# Out:
#                               Train Accuracy Test Accuracy  Train F1  \
# Gradient Boosting                        1.0      0.873874       1.0
# K-Nearest Neighbors                      1.0      0.828829       1.0
# XGBClassifier                            1.0      0.855856       1.0
# Logistic Regression                  0.77551      0.792793  0.123894
# Ridge                               0.770975      0.774775  0.056075
# Extra Trees                              1.0      0.828829       1.0
# AdaBoost                                 1.0      0.810811       1.0
# Passive Aggressive                  0.780045      0.783784  0.126126
# Support Vector Classification            1.0      0.837838       1.0
# Decision Trees                      0.941043       0.81982  0.865979
# Random Forest                            1.0      0.828829       1.0
# Naive Bayes                         0.689342      0.675676  0.406926
#
#                                 Test F1 Best Score  \
# Gradient Boosting              0.681818   0.850511
# K-Nearest Neighbors            0.424242   0.816343
# XGBClassifier                  0.636364   0.857278
# Logistic Regression            0.148148   0.768744
# Ridge                               0.0   0.766445
# Extra Trees                    0.486486   0.825536
# AdaBoost                       0.487805   0.802911
# Passive Aggressive             0.076923   0.755158
# Support Vector Classification      0.55     0.8119
# Decision Trees                  0.52381   0.775689
# Random Forest                  0.457143   0.832354
# Naive Bayes                    0.307692   0.610546
#
#                                                                      Best Params
# Gradient Boosting              {'criterion': 'friedman_mse', 'learning_rate':...
# K-Nearest Neighbors            {'algorithm': 'auto', 'leaf_size': 5, 'n_neigh...
# XGBClassifier                  {'alpha': 0.1, 'gamma': 0.001, 'lambda': 10, '...
# Logistic Regression                {'C': 0.1, 'penalty': 'l1', 'solver': 'saga'}
# Ridge                          {'alpha': 1000, 'fit_intercept': True, 'positi...
# Extra Trees                    {'criterion': 'entropy', 'max_depth': 20, 'max...
# AdaBoost                       {'algorithm': 'SAMME.R', 'learning_rate': 1.5,...
# Passive Aggressive                                 {'C': 0.001, 'loss': 'hinge'}
# Support Vector Classification  {'C': 100, 'decision_function_shape': 'ovo', '...
# Decision Trees                 {'criterion': 'entropy', 'max_depth': None, 'm...
# Random Forest                  {'criterion': 'entropy', 'max_depth': None, 'm...
# Naive Bayes                                               {'var_smoothing': 1.0}
