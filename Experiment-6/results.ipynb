# %%
import pandas as pd
import numpy as np
import json

# %%
models = [
    'Gradient Boosting',
    'K-Nearest Neighbors',

    'XGBClassifier',

    'Logistic Regression',
    'Ridge',
    'Extra Trees',
    'AdaBoost',

    'Passive Aggressive',
    'Support Vector Classification',
    'Decision Trees',

    'Random Forest',
    'Naive Bayes'

]

# %%
len(models)
# Out:
# 12

# %%
result = {}

# %%
for model in models:
    path = model + '.json'
    with open(path, 'r') as f:
        data = json.load(f)
    result[model] = [data['Train Accuracy'], data['Test Accuracy'], data['Train F1'], data['Test F1'], data['Best Score'], data['Best Params']]

# %%
results = pd.DataFrame(result).T
results.columns = ['Train Accuracy', 'Test Accuracy', 'Train F1', 'Test F1', 'Best Score', 'Best Params']
results
# Out:
#                               Train Accuracy Test Accuracy  Train F1  \
# Gradient Boosting                        1.0      0.847826       1.0
# K-Nearest Neighbors                      1.0      0.833333       1.0
# XGBClassifier                            1.0      0.847826       1.0
# Logistic Regression                 0.770531      0.789855   0.11215
# Ridge                               0.719807      0.652174  0.597222
# Extra Trees                              1.0      0.811594       1.0
# AdaBoost                            0.869565      0.811594  0.658228
# Passive Aggressive                  0.780193      0.775362  0.133333
# Support Vector Classification       0.997585      0.804348  0.994924
# Decision Trees                      0.905797      0.673913  0.795812
# Random Forest                       0.995169      0.833333  0.989691
# Naive Bayes                         0.678744      0.681159  0.403587
#
#                                 Test F1 Best Score  \
# Gradient Boosting              0.571429   0.860391
# K-Nearest Neighbors            0.488889   0.783535
# XGBClassifier                  0.588235   0.865315
# Logistic Regression            0.121212   0.719807
# Ridge                          0.466667   0.724903
# Extra Trees                    0.458333   0.807497
# AdaBoost                       0.434783   0.774559
# Passive Aggressive             0.060606   0.714105
# Support Vector Classification   0.44898   0.785146
# Decision Trees                 0.366197   0.728271
# Random Forest                  0.510638   0.819283
# Naive Bayes                    0.333333   0.608615
#
#                                                                      Best Params
# Gradient Boosting              {'criterion': 'friedman_mse', 'learning_rate':...
# K-Nearest Neighbors            {'algorithm': 'auto', 'leaf_size': 5, 'n_neigh...
# XGBClassifier                  {'alpha': 0.1, 'gamma': 0, 'lambda': 0.1, 'lea...
# Logistic Regression                {'C': 0.1, 'penalty': 'l1', 'solver': 'saga'}
# Ridge                          {'alpha': 5, 'fit_intercept': False, 'positive...
# Extra Trees                    {'criterion': 'entropy', 'max_depth': 30, 'max...
# AdaBoost                       {'algorithm': 'SAMME', 'learning_rate': 0.8, '...
# Passive Aggressive                                 {'C': 0.001, 'loss': 'hinge'}
# Support Vector Classification  {'C': 10, 'decision_function_shape': 'ovo', 'g...
# Decision Trees                 {'criterion': 'entropy', 'max_depth': None, 'm...
# Random Forest                  {'criterion': 'entropy', 'max_depth': None, 'm...
# Naive Bayes                                      {'var_smoothing': 0.8111308308}
