# %%
import pandas as pd
import numpy as np
import json

# %%
models = [
    'Gradient Boosting',
    'K-Nearest Neighbors',

    'XGBClassifier',

    'Logistic Regression',
    'Ridge',
    'Extra Trees',
    'AdaBoost',

    'Passive Aggressive',
    'Support Vector Classification',
    'Decision Trees',

    'Random Forest',
    'Naive Bayes'

]

# %%
len(models)
# Out:
# 12

# %%
result = {}

# %%
for model in models:
    path = model + '.json'
    with open(path, 'r') as f:
        data = json.load(f)
    result[model] = [data['Train Accuracy'], data['Test Accuracy'], data['Train F1'], data['Test F1'], data['Best Score'], data['Best Params']]

# %%
results = pd.DataFrame(result).T
results.columns = ['Train Accuracy', 'Test Accuracy', 'Train F1', 'Test F1', 'Best Score', 'Best Params']
results
# Out:
#                               Train Accuracy Test Accuracy  Train F1  \
# Gradient Boosting                        1.0      0.826087       1.0
# K-Nearest Neighbors                      1.0      0.818841       1.0
# XGBClassifier                            1.0      0.833333       1.0
# Logistic Regression                  0.84058      0.782609  0.582278
# Ridge                                0.78744      0.782609  0.266667
# Extra Trees                              1.0      0.818841       1.0
# AdaBoost                            0.809179      0.804348  0.423358
# Passive Aggressive                  0.780193      0.775362  0.133333
# Support Vector Classification       0.997585      0.804348  0.994924
# Decision Trees                      0.900966      0.746377       0.8
# Random Forest                       0.997585       0.84058  0.994872
# Naive Bayes                         0.690821      0.681159  0.412844
#
#                                 Test F1 Best Score  \
# Gradient Boosting              0.555556   0.845401
# K-Nearest Neighbors            0.390244   0.811607
# XGBClassifier                  0.566038   0.857391
# Logistic Regression                 0.4   0.768205
# Ridge                          0.210526   0.765677
# Extra Trees                    0.468085   0.821275
# AdaBoost                        0.27027   0.806759
# Passive Aggressive             0.060606   0.760917
# Support Vector Classification   0.44898   0.816427
# Decision Trees                 0.477612   0.789891
# Random Forest                  0.521739   0.823656
# Naive Bayes                      0.3125   0.618513
#
#                                                                      Best Params
# Gradient Boosting              {'criterion': 'friedman_mse', 'learning_rate':...
# K-Nearest Neighbors            {'algorithm': 'auto', 'leaf_size': 5, 'n_neigh...
# XGBClassifier                  {'alpha': 0, 'gamma': 0.1, 'lambda': 1, 'learn...
# Logistic Regression             {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
# Ridge                          {'alpha': 100, 'fit_intercept': True, 'positiv...
# Extra Trees                    {'criterion': 'entropy', 'max_depth': None, 'm...
# AdaBoost                       {'algorithm': 'SAMME', 'learning_rate': 0.8, '...
# Passive Aggressive                                 {'C': 0.001, 'loss': 'hinge'}
# Support Vector Classification  {'C': 10, 'decision_function_shape': 'ovo', 'g...
# Decision Trees                 {'criterion': 'entropy', 'max_depth': 10, 'max...
# Random Forest                  {'criterion': 'entropy', 'max_depth': 10, 'max...
# Naive Bayes                                               {'var_smoothing': 1.0}
